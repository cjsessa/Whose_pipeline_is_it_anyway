# %%
# import dependencies
import requests
import json
from pprint import pprint
import pandas as pd
from config import KEY
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-aa3b82402ab0> in <module>
#       4 from pprint import pprint
#       5 import pandas as pd
# ----> 6 from config import KEY
#
# ModuleNotFoundError: No module named 'config'

# %%
# Save config information
ATL_query_url = "https://api.tomtom.com/traffic/services/4/incidentDetails/s3/6841263.950712%2C511972.674418%2C6886056.049288%2C582676.925582/10/-1/json?key=KEY"

# %%
ATL_response = requests.get(ATL_query_url)
ATL_json = ATL_response.json()

# ATL_response = json.loads(ATL_response.content.decode('utf-8'))
print(ATL_response)

# print(json.loads(ATL_response.content.decode('utf-8')))

# %%
query_url = 'https://traffic.ls.hereapi.com/traffic/6.3/incidents.json?apiKey=GOlqCjGPNjWRXr5ygmE_kBXSBYzMklXWGeM62HxlwdQ&bbox=33.826,-84.222;33.671,-84.561'

# %%
response = requests.get(query_url)
json = response.json()
json

# %%
#read atlanta crash csv and update data frame 
atl_crashes = pd.read_csv("data/atlanta_crashes.csv")
atl_crashes = atl_crashes.dropna()
atl_crashes = atl_crashes.rename(columns={"Unnamed: 1": "January", "Unnamed: 2": "February", "Unnamed: 3": "March", "Unnamed: 4": "April",
                  "Unnamed: 5": "May", "Unnamed: 6": "June", "Unnamed: 7": "July", "Unnamed: 8": "August",
                  "Unnamed: 9": "September", "Unnamed: 10": "October", "Unnamed: 11": "November", "Unnamed: 12": "December",
                  "Unnamed: 13": "Total"})
atl_crashes
# Out:
#    National Highway Traffic Safety Administration (NHTSA) Motor Vehicle Crash Data Querying and Reporting  \
# 9                                                2004
# 10                                               2005
# 11                                               2006
# 12                                               2007
# 13                                               2008
# 14                                               2009
# 15                                               2010
# 16                                               2011
# 17                                               2012
# 18                                               2013
# 19                                               2014
# 20                                               2015
# 21                                               2016
# 22                                               2017
# 23                                               2018
# ...

# %%
#read pittsburgh crash csv and update data frame 
pitt_crashes = pd.read_csv("data/pittsburgh_crashes.csv")
pitt_crashes = pitt_crashes.dropna()
pitt_crashes = pitt_crashes.rename(columns={"Unnamed: 1": "January", "Unnamed: 2": "February", "Unnamed: 3": "March", "Unnamed: 4": "April",
                  "Unnamed: 5": "May", "Unnamed: 6": "June", "Unnamed: 7": "July", "Unnamed: 8": "August",
                  "Unnamed: 9": "September", "Unnamed: 10": "October", "Unnamed: 11": "November", "Unnamed: 12": "December",
                  "Unnamed: 13": "Total"})
pitt_crashes
# Out:
#    National Highway Traffic Safety Administration (NHTSA) Motor Vehicle Crash Data Querying and Reporting  \
# 9                                                2004
# 10                                               2005
# 11                                               2006
# 12                                               2007
# 13                                               2008
# 14                                               2009
# 15                                               2010
# 16                                               2011
# 17                                               2012
# 18                                               2013
# 19                                               2014
# 20                                               2015
# 21                                               2016
# 22                                               2017
# 23                                               2018
# ...

# %%
#read cincinnati crash csv and update data frame 
cin_crashes = pd.read_csv("data/cincinnati_crashes.csv")
cin_crashes = cin_crashes.dropna()
cin_crashes = cin_crashes.rename(columns={"Unnamed: 1": "January", "Unnamed: 2": "February", "Unnamed: 3": "March", "Unnamed: 4": "April",
                  "Unnamed: 5": "May", "Unnamed: 6": "June", "Unnamed: 7": "July", "Unnamed: 8": "August",
                  "Unnamed: 9": "September", "Unnamed: 10": "October", "Unnamed: 11": "November", "Unnamed: 12": "December",
                  "Unnamed: 13": "Total"})
cin_crashes
# Out:
#    National Highway Traffic Safety Administration (NHTSA) Motor Vehicle Crash Data Querying and Reporting  \
# 9                                                2004
# 10                                               2005
# 11                                               2006
# 12                                               2007
# 13                                               2008
# 14                                               2009
# 15                                               2010
# 16                                               2011
# 17                                               2012
# 18                                               2013
# 19                                               2014
# 20                                               2015
# 21                                               2016
# 22                                               2017
# 23                                               2018
# ...

# %%
#read chico crash csv and update data frame 
chico_crashes = pd.read_csv("data/chico_crashes.csv")
chico_crashes = chico_crashes.dropna()
chico_crashes = chico_crashes.rename(columns={"Unnamed: 1": "January", "Unnamed: 2": "February", "Unnamed: 3": "March", "Unnamed: 4": "April",
                  "Unnamed: 5": "May", "Unnamed: 6": "June", "Unnamed: 7": "July", "Unnamed: 8": "August",
                  "Unnamed: 9": "September", "Unnamed: 10": "October", "Unnamed: 11": "November", "Unnamed: 12": "December",
                  "Unnamed: 13": "Total"})
chico_crashes
# Out:
#    National Highway Traffic Safety Administration (NHTSA) Motor Vehicle Crash Data Querying and Reporting  \
# 9                                                2004
# 10                                               2005
# 11                                               2006
# 12                                               2007
# 13                                               2008
# 14                                               2009
# 15                                               2010
# 16                                               2011
# 17                                               2012
# 18                                               2013
# 19                                               2014
# 20                                               2015
# 21                                               2016
# 22                                               2017
# 23                                               2018
# ...

# %%
#read brownsville crash csv and update data frame 
bville_crashes = pd.read_csv("data/brownsville_crashes.csv")
bville_crashes = bville_crashes.dropna()
bville_crashes = bville_crashes.rename(columns={"Unnamed: 1": "January", "Unnamed: 2": "February", "Unnamed: 3": "March", "Unnamed: 4": "April",
                  "Unnamed: 5": "May", "Unnamed: 6": "June", "Unnamed: 7": "July", "Unnamed: 8": "August",
                  "Unnamed: 9": "September", "Unnamed: 10": "October", "Unnamed: 11": "November", "Unnamed: 12": "December",
                  "Unnamed: 13": "Total"})
bville_crashes
# Out:
#    National Highway Traffic Safety Administration (NHTSA) Motor Vehicle Crash Data Querying and Reporting  \
# 9                                                2004
# 10                                               2005
# 11                                               2006
# 12                                               2007
# 13                                               2008
# 14                                               2009
# 15                                               2010
# 16                                               2011
# 17                                               2012
# 18                                               2013
# 19                                               2014
# 20                                               2015
# 21                                               2016
# 22                                               2017
# 23                                               2018
# ...

# %%
#read national crash csv and update data frame 
national_crashes = pd.read_csv("data/national_crashes.csv")
national_crashes = national_crashes.dropna()
national_crashes = national_crashes.rename(columns={"Unnamed: 1": "January", "Unnamed: 2": "February", "Unnamed: 3": "March", "Unnamed: 4": "April",
                  "Unnamed: 5": "May", "Unnamed: 6": "June", "Unnamed: 7": "July", "Unnamed: 8": "August",
                  "Unnamed: 9": "September", "Unnamed: 10": "October", "Unnamed: 11": "November", "Unnamed: 12": "December",
                  "Unnamed: 13": "Total"})
national_crashes
# Out:
#    National Highway Traffic Safety Administration (NHTSA) Motor Vehicle Crash Data Querying and Reporting  \
# 7                                                2004
# 8                                                2005
# 9                                                2006
# 10                                               2007
# 11                                               2008
# 12                                               2009
# 13                                               2010
# 14                                               2011
# 15                                               2012
# 17                                               2013
# 18                                               2014
# 19                                               2015
# 20                                               2016
# 21                                               2017
# 22                                               2018
# ...

# %%
# read in oil csv 
oil_prices = pd.read_csv("data/oil_dow_prices.csv")
oil_prices
# Out:
#      Unnamed: 0        date  Crude_Oil_Price   Close Price
# 0             0  1985-01-01            24.26   1289.090007
# 1             1  1985-02-01            23.64   1283.232101
# 2             2  1985-03-01            23.89   1268.829997
# 3             3  1985-04-01            24.19   1266.358114
# 4             4  1985-05-01            24.18   1279.397738
# ..          ...         ...              ...           ...
# 416         416  2019-09-01            55.07  26900.213964
# 417         417  2019-10-01            53.14  26736.797724
# 418         418  2019-11-01            54.96  27797.046094
# 419         419  2019-12-01            58.41  28167.005768
# 420         420  2020-01-01            56.86  28879.994326
#
# [421 rows x 4 columns]
